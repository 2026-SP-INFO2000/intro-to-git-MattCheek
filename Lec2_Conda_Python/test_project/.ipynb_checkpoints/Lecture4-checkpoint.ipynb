# %% [markdown]
# ## First lecture with python notebook

# %% [markdown]
# ### Creates a folder with "Hello" inside the res folder.

# %%
with open("res/output.txt", "w") as f:
    f.write("Hello\n")
    f.close()
    
print("Done. Check folder.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 with open("res/output.txt", "w") as f:
#       2     f.write("Hello\n")
#       3     f.close()
#
# File ~\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'res/output.txt'

# %% [markdown]
# ### Asks for first and last name, then prints your full name along with the length of each individual name.

# %%
name = input("What is your name? ")
lname = input("What is your last name? ")
print(name + " " + lname)
print("The length of your first name is " + str(len(name)) + " letters.")
print("The length of your last name is " + str(len(lname)) + " letters.")
# Out:
# What is your name?  Matt
# What is your last name?  Cheek
# Matt Cheek
# The length of your first name is 4 letters.
# The lenght of your last name is 5 letters.
